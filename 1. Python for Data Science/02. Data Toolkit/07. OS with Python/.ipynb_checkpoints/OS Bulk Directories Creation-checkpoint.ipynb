# %%
import os

# %%
for i in range(100):
    name='Hello/Arya ' + str(i+1)  # i+1 will print 1-100, otherwise 0-99
#     print(name)
    os.mkdir(name)

# %%
os.listdir('Hello')
# Out:
# ['Arya 1',
#  'Arya 10',
#  'Arya 100',
#  'Arya 11',
#  'Arya 12',
#  'Arya 13',
#  'Arya 14',
#  'Arya 15',
#  'Arya 16',
#  'Arya 17',
#  'Arya 18',
#  'Arya 19',
#  'Arya 2',
#  'Arya 20',
#  'Arya 21',
#  'Arya 22',
#  'Arya 23',
#  'Arya 24',
#  'Arya 25',
#  'Arya 26',
#  'Arya 27',
#  'Arya 28',
#  'Arya 29',
#  'Arya 3',
#  'Arya 30',
#  'Arya 31',
#  'Arya 32',
#  'Arya 33',
#  'Arya 34',
#  'Arya 35',
#  'Arya 36',
#  'Arya 37',
#  'Arya 38',
#  'Arya 39',
#  'Arya 4',
#  'Arya 40',
#  'Arya 41',
#  'Arya 42',
#  'Arya 43',
#  'Arya 44',
#  'Arya 45',
#  'Arya 46',
#  'Arya 47',
#  'Arya 48',
#  'Arya 49',
#  'Arya 5',
#  'Arya 50',
#  'Arya 51',
#  'Arya 52',
#  'Arya 53',
#  'Arya 54',
#  'Arya 55',
#  'Arya 56',
#  'Arya 57',
#  'Arya 58',
#  'Arya 59',
#  'Arya 6',
#  'Arya 60',
#  'Arya 61',
#  'Arya 62',
#  'Arya 63',
#  'Arya 64',
#  'Arya 65',
#  'Arya 66',
#  'Arya 67',
#  'Arya 68',
#  'Arya 69',
#  'Arya 7',
#  'Arya 70',
#  'Arya 71',
#  'Arya 72',
# ...

# %%
n = 'Arya'
os.mkdir(n)
for i in range(500):
    name = n + '/' + 'Aryadeep ' + str(i+1)
#     print(name)
    os.mkdir(name)

# %%
os.listdir('Arya')
# Out:
# ['Aryadeep 1',
#  'Aryadeep 10',
#  'Aryadeep 100',
#  'Aryadeep 101',
#  'Aryadeep 102',
#  'Aryadeep 103',
#  'Aryadeep 104',
#  'Aryadeep 105',
#  'Aryadeep 106',
#  'Aryadeep 107',
#  'Aryadeep 108',
#  'Aryadeep 109',
#  'Aryadeep 11',
#  'Aryadeep 110',
#  'Aryadeep 111',
#  'Aryadeep 112',
#  'Aryadeep 113',
#  'Aryadeep 114',
#  'Aryadeep 115',
#  'Aryadeep 116',
#  'Aryadeep 117',
#  'Aryadeep 118',
#  'Aryadeep 119',
#  'Aryadeep 12',
#  'Aryadeep 120',
#  'Aryadeep 121',
#  'Aryadeep 122',
#  'Aryadeep 123',
#  'Aryadeep 124',
#  'Aryadeep 125',
#  'Aryadeep 126',
#  'Aryadeep 127',
#  'Aryadeep 128',
#  'Aryadeep 129',
#  'Aryadeep 13',
#  'Aryadeep 130',
#  'Aryadeep 131',
#  'Aryadeep 132',
#  'Aryadeep 133',
#  'Aryadeep 134',
#  'Aryadeep 135',
#  'Aryadeep 136',
#  'Aryadeep 137',
#  'Aryadeep 138',
#  'Aryadeep 139',
#  'Aryadeep 14',
#  'Aryadeep 140',
#  'Aryadeep 141',
#  'Aryadeep 142',
#  'Aryadeep 143',
#  'Aryadeep 144',
#  'Aryadeep 145',
#  'Aryadeep 146',
# ...
